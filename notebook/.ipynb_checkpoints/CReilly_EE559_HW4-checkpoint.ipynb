# %%
# EE559 Homework #4
# Author: Creed Reilly
# USC ID: 6721694310
# Date: 06/29/2021

# %%
# Import Data Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
import statsmodels.api as sm
from sklearn import preprocessing
import random as rand

# %%
# Question 7

# %%
# Part A - Download the Data

# Data located in '../data'

# Had to clean up bending2, dataset4.csv (had no commas)

# sitting dataset5.csv only had 479 entries, so there is one entry of 0 (small enough error, not worried about it)

# %%
# Part B - Segregate training and test data

bending1 = pd.DataFrame(); # 0
bending2 = pd.DataFrame(); # 0
cycling = pd.DataFrame();  # 1
lying = pd.DataFrame();    # 2
sitting = pd.DataFrame();  # 3
standing = pd.DataFrame(); # 4
walking = pd.DataFrame();  # 5
testData1 = pd.DataFrame();

trainingData = np.zeros([480,7]);
testData = np.zeros([480,7]);


#trainingData[:,:,0] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]))

# READ IN TRAINING DATA
trainingLabel = 0; # outcome for each instance

# Read in bending1 data
counter = np.arange(5)+3; # keep the 1st 2 sets as test sets
for i in counter: 
    title = '../data/bending1/dataset' + str(i) + '.csv'; # create title for reading in file
    bending1 = bending1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,0))
    
# Read in bending2 data
counter = np.arange(4)+3; # keep the 1st 2 sets as test sets
for i in counter: 
    title = '../data/bending2/dataset' + str(i) + '.csv'; # create title for reading in file
    bending2 = bending2.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,0))

# Read in cycling, lying, sitting, standing, walking data
counter = np.arange(12)+4; # keep the 1st 3 sets as test sets
for i in counter: 
    title = '../data/cycling/dataset' + str(i) + '.csv'; # create title for reading in file
    cycling = cycling.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,1))
 
    title = '../data/lying/dataset' + str(i) + '.csv'; # create title for reading in file
    lying = lying.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,2))
    
    title = '../data/sitting/dataset' + str(i) + '.csv'; # create title for reading in file
    sitting = sitting.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,3))
    
    title = '../data/standing/dataset' + str(i) + '.csv'; # create title for reading in file
    standing = standing.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,4))
    
    title = '../data/walking/dataset' + str(i) + '.csv'; # create title for reading in file
    walking = walking.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    trainingData = np.dstack((trainingData, dum));
    trainingLabel = np.dstack((trainingLabel,5))

# READ IN TEST DATA

# Read in bending1 data
counter = np.arange(2)+1;
for i in counter: 
    title = '../data/bending1/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
# Read in bending2 data
counter = np.arange(2)+1;
for i in counter: 
    title = '../data/bending2/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
# Read in cycling, lying, sitting, standing, walking data
counter = np.arange(3)+1;
for i in counter: 
    title = '../data/cycling/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
    title = '../data/lying/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
    title = '../data/sitting/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
    title = '../data/standing/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
    title = '../data/walking/dataset' + str(i) + '.csv'; # create title for reading in file
    testData1 = testData1.append(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]),ignore_index=True)
    n = len(np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6])));
    dum = np.zeros([480,7]);
    dum[0:n,:] = np.array(pd.read_csv(title,skiprows = 4, usecols = [0,1,2,3,4,5,6]));
    testData = np.dstack((testData, dum));
    
trainingData = np.delete(trainingData,0,2); # delete initialization array of 0's
trainingLabel = np.delete(trainingLabel,0); # delete initialization array of 0's
testData = np.delete(testData,0,2); # delete initialization array of 0's

# %%
# Part C - Feature Extraction (using trainingData and testData)

# Part Ci: List time-domain features used in time-series classification. They include:
#     mean, minimum, maximum, std dev, skewness, kurtosis

# Part Cii: Extract minimum, maximum, mean, median, std dev, 1st quartile, 3rd quartile, for all 6 time series

instanceMx = np.dstack((trainingData,testData)); # create mx for for loop - instance determination

n = 88; # number of instances
z = 6; # number of time series
l = 7; # number of time series features
featureExtraction = np.zeros([n,l*z+1]);

for i in np.arange(n): # for-loop for n rows
    featureExtraction[i,0] = i+1; # define instance number
    
    for j in np.arange(z): # for loop for each time series
        featureExtraction[i,l*j+1] = instanceMx[:,j+1,i].min(); # min of time series
        featureExtraction[i,l*j+2] = instanceMx[:,j+1,i].max(); # max of time series
        featureExtraction[i,l*j+3] = instanceMx[:,j+1,i].mean(); # mean of time series
        featureExtraction[i,l*j+4] = np.median(instanceMx[:,j+1,i]); # median of time series
        featureExtraction[i,l*j+5] = instanceMx[:,j+1,i].std(); # std of time series
        featureExtraction[i,l*j+6] = np.quantile(instanceMx[:,j+1,i], 0.25); # 1st quartile of time series
        featureExtraction[i,l*j+7] = np.quantile(instanceMx[:,j+1,i], 0.75); # 3rd quartile of time series

# Create the column headers in for-loop and create dataframe
cols = 'Instance';
for i in np.arange(z):
    cols = np.hstack((cols,'min' + str(i+1),'max' + str(i+1),'mean' + str(i+1),'med' + str(i+1),'std' + str(i+1),
                     '1stqrt' + str(i+1),'3rdqrt' + str(i+1),));

instanceDF = pd.DataFrame(data=featureExtraction,columns=cols);

# Print resultant dataframe
instanceDF
# Out:
#     Instance   min1   max1      mean1   med1      std1  1stqrt1  3rdqrt1  \
# 0        1.0  35.00  47.40  43.954500  44.33  1.557210    43.00  45.0000
# 1        2.0  33.00  47.75  42.179812  43.50  3.666840    39.15  45.0000
# 2        3.0  33.00  45.75  41.678063  41.75  2.241152    41.33  42.7500
# 3        4.0  37.00  48.00  43.454958  43.25  1.384653    42.50  45.0000
# 4        5.0  36.25  48.00  43.969125  44.50  1.616677    43.31  44.6700
# ..       ...    ...    ...        ...    ...       ...      ...      ...
# 83      84.0  22.00  44.67  37.058708  36.00  3.706313    34.50  40.0625
# 84      85.0  48.00  48.25  48.004167  48.00  0.032005    48.00  48.0000
# 85      86.0  44.50  46.75  45.239667  45.00  0.429467    45.00  45.3300
# 86      87.0  32.75  47.00  42.760562  44.50  3.395376    41.33  45.3725
# 87      88.0  15.00  46.75  34.660583  35.00  5.309571    31.00  38.2500
#
#     min2   max2  ...      std5  1stqrt5  3rdqrt5  min6  max6     mean6  med6  \
# ...

# %%
# Part Ciii - estimate std deviation of each column
k = featureExtraction.shape[1]-1;
n = featureExtraction.shape[0];
standardDeviation = np.zeros(k);

for i in np.arange(k):
    feature = featureExtraction[:,i+1];
    standardDeviation[i] = sum((feature - feature.mean())**2)/(n-8-1);
print('Estimated Std Dev for each instance = \n\n',standardDeviation)
# Out:
# Estimated Std Dev for each instance =
#
#  [1.09150416e+02 2.12658996e+01 3.13441899e+01 3.25910689e+01
#  3.40450440e+00 4.17012656e+01 2.90828293e+01 0.00000000e+00
#  2.82267962e+01 2.72894785e+00 2.19640154e+00 8.58999554e-01
#  9.86345235e-01 4.97415044e+00 9.62579883e+00 2.61737383e+01
#  1.76915264e+01 1.79423682e+01 9.85634112e-01 1.96117925e+01
#  1.91647587e+01 0.00000000e+00 5.25107801e+00 1.49755279e+00
#  1.44526438e+00 2.30771197e-01 7.83764467e-01 2.65434712e+00
#  4.14067924e+01 3.62997228e+01 3.54743912e+01 3.72228577e+01
#  1.15529792e+00 4.09306234e+01 3.36986555e+01 2.31390967e-03
#  6.98749078e+00 1.46867229e+00 1.29996332e+00 2.94443646e-01
#  6.33722762e-01 2.55642815e+00]

# %%
# Part Ciii - Bootstrap to see confidence interval of std. deviation

# Want to perform 20 bootstrap samples, so we can then choose the 5% delta from mean and the 95% delta from the mean,
# which will give us a 90% interval.

# draw 88 samples for each bootstrap set to determine std deviation...
z = 20; # how many bootstrap datasets we need...
q = featureExtraction.shape[1]-1; # number of features we are bootstrapping
n = featureExtraction.shape[0]; # number of samples for each bootstrap set
l = np.arange(n); # possible instance values

bootstrap = np.zeros(featureExtraction.shape) # create memory loc for bootstrap featureExtraction
bootstrapDev = np.zeros([q,z]) # create memory for Std Dev of each sample
deltas = bootstrapDev; # same set of zeros to start out
for i in np.arange(z): # perform 20 bootstrap samples
    
    v = rand.choices(l, k=n); # create array of new sample indices, with replacement
    for j in np.arange(n):
        bootstrap[j,:] = featureExtraction[v[j],:]; # create bootstrap set
    
    # Capture standard deviation of bootstrap
    for u in np.arange(q):
        feature = bootstrap[:,u+1];
        bootstrapDev[u,i] = sum((feature - feature.mean())**2)/(n-8-1);

for i in np.arange(z): # for loop to calculate deltas
    deltas[:,i] = standardDeviation - bootstrapDev[:,i];

deltas = np.sort(deltas,axis=1) # sort each column from lowest to highest.

output = np.zeros([q,2])
output[:,0] = standardDeviation.T-deltas[:,18]
output[:,1] = standardDeviation.T-deltas[:,1]

print('---Confidence Interval for Standard Deviation---\n')
print('90% Bootstrap Confidence Int. [5%, 95%] :\n')

print('\n', output)
# Out:
# ---Confidence Interval for Standard Deviation---
#
# 90% Bootstrap Confidence Int. [5%, 95%] :
#
#
#  [[8.99085620e+01 1.22325050e+02]
#  [1.09395556e+01 2.69415162e+01]
#  [2.33919084e+01 3.25291816e+01]
#  [2.68379537e+01 3.50101360e+01]
#  [2.85650592e+00 4.07471884e+00]
#  [3.45752836e+01 4.44703827e+01]
#  [1.96727839e+01 3.19809958e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [2.34999563e+01 3.05902563e+01]
#  [2.26095622e+00 3.26288199e+00]
#  [1.75570316e+00 2.70321058e+00]
#  [7.20361380e-01 9.77641799e-01]
#  [8.02289513e-01 1.22770030e+00]
#  [4.18449937e+00 5.91620319e+00]
#  [8.53120109e+00 1.13665183e+01]
#  [2.19009852e+01 3.32363183e+01]
#  [1.28299666e+01 2.15055668e+01]
#  [1.26115442e+01 2.17351741e+01]
#  [8.36147602e-01 1.26638641e+00]
#  [1.50415039e+01 2.30125221e+01]
#  [1.40459131e+01 2.30989179e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [4.48263221e+00 5.97751322e+00]
#  [1.30906931e+00 1.60351065e+00]
#  [1.24540357e+00 1.56816870e+00]
# ...

# %%
# Part Civ

X = instanceDF.iloc[0:69,1:]
y = trainingLabel;

print(sm.OLS(y,X).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.951
# Method:                 Least Squares   F-statistic:                              34.47
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):                    3.04e-16
# Time:                        10:05:17   Log-Likelihood:                         -41.862
# No. Observations:                  69   AIC:                                      163.7
# Df Residuals:                      29   BIC:                                      253.1
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Part Civ

# Since t and z distribution is identical above ~40 samples, I can use lin regression p-vals to find the most statistically
# significant features. Those features are (keeping p-vals < 0.1):
# min    : 1
# max    : 1
# mean   : 1
# med    : 2
# std    : 1
# 1stqrt : 4
# 3rdqrt : 1

#                 coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# min1           0.0592      0.026      2.273      0.031       0.006       0.112
# 1stqrt2       -2.3119      1.162     -1.990      0.056      -4.687       0.064
# max3          -0.2052      0.106     -1.935      0.063      -0.422       0.012
# 1stqrt3        0.8572      0.375      2.285      0.030       0.090       1.624
# med4          -3.9647      1.846     -2.148      0.040      -7.740      -0.190
# std4          -4.4379      2.569     -1.728      0.095      -9.691       0.815
# mean5         -3.5340      1.219     -2.900      0.007      -6.026      -1.042
# med5           0.6844      0.393      1.742      0.092      -0.119       1.488
# 1stqrt5        1.3453      0.421      3.195      0.003       0.484       2.206
# 3rdqrt5        1.1662      0.565      2.065      0.048       0.011       2.321
# 1stqrt6        4.7375      2.234      2.121      0.043       0.168       9.307

# %%
# From the above, using raw values, the most important features are:
# 1. 1st Quartile
# 2. Median
# 3. Mean - this was a tie with others, but it had the strongest correlation among the other features only listed once.

# %%
# Let's try this again with normalized values:

x = instanceDF.values;
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x);
instanceDFmin_max = pd.DataFrame(x_scaled,columns=cols);

X = instanceDFmin_max.iloc[0:69,1:]
y = trainingLabel;

print(sm.OLS(y,X).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              38.93
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):                    5.63e-17
# Time:                        10:05:17   Log-Likelihood:                         -37.751
# No. Observations:                  69   AIC:                                      155.5
# Df Residuals:                      29   BIC:                                      244.9
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Using normalized values, our most statistically significant features are (keeping p-vals < 0.1):
# min    : 1
# max    : 1
# mean   : 3
# med    : 3
# std    : 1
# 1stqrt : 2
# 3rdqrt : 1


#                 coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# min1           1.6197      0.791      2.047      0.050       0.002       3.238
# mean1        -30.5871     13.955     -2.192      0.037     -59.129      -2.045
# med1          13.0522      3.860      3.382      0.002       5.158      20.946
# med2           8.8213      5.017      1.758      0.089      -1.440      19.082
# max3          -4.2486      2.156     -1.971      0.058      -8.658       0.161
# mean4         20.7334     11.398      1.819      0.079      -2.578      44.045
# med4         -18.5299      5.240     -3.536      0.001     -29.247      -7.813
# std4          -6.4606      3.139     -2.058      0.049     -12.881      -0.040
# mean5        -55.8434     20.105     -2.778      0.009     -96.962     -14.725
# 1stqrt5       30.1739     10.132      2.978      0.006       9.451      50.897
# 3rdqrt5       20.7133     11.832      1.751      0.091      -3.486      44.913
# 1stqrt6        8.0306      4.265      1.883      0.070      -0.692      16.753

# %%
# From the above, using normalized values, the most important features are:
# 1. Mean
# 2. Median
# 3. 1st Quartile

# This is the same as the raw values, but provides a higher fidelity fit (R2 of 0.982 v. 0.979)

# %%
trainingLabel.shape
# Out:
# (69,)

# %%
# Part Cv - Process data to pull out bending motion to get color difference.

trainingFeatures = featureExtraction[:69,:]
bendingFeatures =  np.zeros([1,featureExtraction.shape[1]]); # go through the training features to grab bending data
notbendingFeatures = np.zeros([1,featureExtraction.shape[1]]); # grab everything else...
for i in np.arange(trainingFeatures.shape[0]): 
    if trainingLabel[i] == 0:
        bendingFeatures = np.vstack((bendingFeatures,trainingFeatures[i,:])) # grab features of bending data
    else:
        notbendingFeatures = np.vstack((notbendingFeatures,trainingFeatures[i,:])) # grab features of not-bending data
        
bendingFeatures = np.delete(bendingFeatures,0,0)
notbendingFeatures = np.delete(notbendingFeatures,0,0)

# %%
# Part Cv - plot (mean v median), (mean v 1stqrt), (med v 1stqrt) for time series 1, 2, and 6

# %%
# TIME SERIES 1

n = 1;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# TIME SERIES 2

n = 2;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# TIME SERIES 3

n = 3;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# TIME SERIES 4

n = 4;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# TIME SERIES 5

n = 5;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# TIME SERIES 6

n = 6;
figs, axs = plt.subplots(1,3); # create subplots for the 3 different scatter plots.

bendMean = bendingFeatures[:,7*(n-1)+3]
bendMed = bendingFeatures[:,7*(n-1)+4]
bend1qrt = bendingFeatures[:,7*(n-1)+6]

notbendMean = notbendingFeatures[:,7*(n-1)+3]
notbendMed = notbendingFeatures[:,7*(n-1)+4]
notbend1qrt = notbendingFeatures[:,7*(n-1)+6]

title = 'Time Series ' + str(n) + ' : Feature Correlation';
figs.suptitle(title)
axs[0].scatter(notbendMean,notbendMed, color = 'black', marker = '+')
axs[0].scatter(bendMean,bendMed, color = 'red')
axs[0].set_xlabel('Mean')
axs[0].set_ylabel('Median')

axs[1].scatter(notbendMean,notbend1qrt, color = 'black', marker = '+')
axs[1].scatter(bendMean,bend1qrt, color = 'red')
axs[1].set_xlabel('Mean')
axs[1].set_ylabel('1st Quartile')

axs[2].scatter(notbendMed,notbend1qrt, color = 'black', marker = '+')
axs[2].scatter(bendMed,bend1qrt, color = 'red')
axs[2].set_xlabel('Median')
axs[2].set_ylabel('1st Quartile')

figs.legend(['Non-Bending','Bending'],loc = 'upper left')
plt.tight_layout()

# %%
# Stay tuned for HW 5...
